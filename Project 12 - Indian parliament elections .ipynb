# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
lp=pd.read_excel('Indian_Parliament_elections.xlsx')
lp
# Out:
#                                        Political Party  No of Candidates  \
# 0                                Bharatiya Lok Dal BLD                 3
# 1                         Communist Party of India CPI                 4
# 2               Communist Party of India (Marxist) CPM                 9
# 3               Indian National Congress (Indira) INCI                11
# 4                            Others / Independents IND                23
# ..                                                 ...               ...
# 186                   Secular Democratic Congress SDC                  2
# 187             Social Democratic Party of India SDPI                 10
# 188                       Samajwadi Forward Block SFB                  1
# 189   Socialist Unity Centre of India (Communist) S...                 9
# 190                Viduthalai Chirutahikal Katchi VCK                  1
#
#      Seats Won    Votes  Percentage  year  Unnamed: 6 Unnamed: 7
# ...

# %%
lp.drop(['Unnamed: 6','Unnamed: 7'],axis=1,inplace=True)
lp
# Out:
#                                        Political Party  No of Candidates  \
# 0                                Bharatiya Lok Dal BLD                 3
# 1                         Communist Party of India CPI                 4
# 2               Communist Party of India (Marxist) CPM                 9
# 3               Indian National Congress (Indira) INCI                11
# 4                            Others / Independents IND                23
# ..                                                 ...               ...
# 186                   Secular Democratic Congress SDC                  2
# 187             Social Democratic Party of India SDPI                 10
# 188                       Samajwadi Forward Block SFB                  1
# 189   Socialist Unity Centre of India (Communist) S...                 9
# 190                Viduthalai Chirutahikal Katchi VCK                  1
#
#      Seats Won    Votes  Percentage  year
# 0            0   637206        7.19  1977
# ...

# %%
lp.shape
# Out:
# (191, 6)

# %%
lp.head()
# Out:
#                           Political Party  No of Candidates  Seats Won  \
# 0                   Bharatiya Lok Dal BLD                 3          0
# 1            Communist Party of India CPI                 4          4
# 2  Communist Party of India (Marxist) CPM                 9          0
# 3  Indian National Congress (Indira) INCI                11         11
# 4               Others / Independents IND                23          0
#
#      Votes  Percentage  year
# 0   637206        7.19  1977
# 1   919359       10.38  1977
# 2  1800193       20.33  1977
# 3  2579745       29.13  1977
# 4   214261        2.42  1977

# %%
lp.columns
# Out:
# Index(['Political Party', 'No of Candidates', 'Seats Won', 'Votes',
#        'Percentage', 'year'],
#       dtype='object')

# %% [markdown]
# # 1.check whether null values are present in the given data.

# %%
lp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Political Party   191 non-null    object
#  1   No of Candidates  191 non-null    int64
#  2   Seats Won         191 non-null    int64
#  3   Votes             191 non-null    int64
#  4   Percentage        191 non-null    float64
#  5   year              191 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 9.1+ KB

# %%
lp.isna().sum()
# Out:
# Political Party     0
# No of Candidates    0
# Seats Won           0
# Votes               0
# Percentage          0
# year                0
# dtype: int64

# %% [markdown]
# # 2. find the number of year

# %%
lp['year'].value_counts()
# Out:
# 2014    28
# 2019    27
# 2009    25
# 2004    21
# 1999    18
# 1998    17
# 1984    16
# 1986    15
# 1980    13
# 1977    11
# Name: year, dtype: int64

# %% [markdown]
# # 3. find the number of No of Candidates

# %%
lp['No of Candidates'].count()
# Out:
# 191

# %% [markdown]
# # 4. find the number of Seats Won

# %%
lp['Seats Won'].sum()
# Out:
# 200

# %% [markdown]
# # 5. find the total year of each Political Party

# %%
p=lp.groupby('Political Party').sum()['year']
p
# Out:
# Political Party
#   All Kerala MGR Dravida Munnetra Party ADMP           2004
#   Communist Party of India (Marxist-Leninist) CPML     2004
#   Communist Party of India (Marxist-Leninist) CPML     1999
#   Communist Party of India CPI                         2014
#   Independents (Janata) SJP                            1998
#                                                        ...
# Others / Independents IND                              7927
# Revolutionary Socialist Party (Bolshevik) RSPB         2014
# Revolutionary Socialist Party RSP                      3963
# Social Action Party SAP                                2014
# Socialist Republican Party SRP                         1980
# Name: year, Length: 122, dtype: int64

# %% [markdown]
# # 6. find the Average Percentage of each Political Party

# %%
p=lp.groupby('Political Party').mean()['Percentage']
p
# Out:
# Political Party
#   All Kerala MGR Dravida Munnetra Party ADMP           0.010
#   Communist Party of India (Marxist-Leninist) CPML     0.020
#   Communist Party of India (Marxist-Leninist) CPML     0.150
#   Communist Party of India CPI                         7.590
#   Independents (Janata) SJP                            0.040
#                                                        ...
# Others / Independents IND                              2.495
# Revolutionary Socialist Party (Bolshevik) RSPB         0.240
# Revolutionary Socialist Party RSP                      2.745
# Social Action Party SAP                                0.000
# Socialist Republican Party SRP                         1.980
# Name: Percentage, Length: 122, dtype: float64

# %% [markdown]
# # 7. find the Average Percentage of each No of Candidates

# %%
p=lp.groupby('No of Candidates').mean()['Percentage']
p
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_22700\4171275968.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   p=lp.groupby('No of Candidates').mean()['Percentage']
# No of Candidates
# 1      61.912090
# 2       2.664167
# 3       2.710000
# 4       4.730000
# 5       0.664286
# 6       7.960000
# 7       9.670000
# 8       0.113333
# 9      13.703333
# 10     16.782500
# 11     27.725000
# 12     27.900000
# 13     32.390000
# 14     15.857500
# 15     11.420000
# 16     25.433333
# 17     38.345000
# 18     10.330000
# 19      7.106667
# 20      1.927500
# 23      2.420000
# 52      2.630000
# 66      0.920000
# 84      2.070000
# 102     1.300000
# 103     1.160000
# 105     3.990000
# 113     0.790000
# 115    10.870000
# 131     0.940000
# Name: Percentage, dtype: float64

# %% [markdown]
# # 8. find the Number Seats Won of each No of Candidates

# %%
p=lp.groupby('No of Candidates').count()['Seats Won']
p
# Out:
# No of Candidates
# 1      67
# 2      36
# 3      12
# 4      17
# 5       7
# 6       2
# 7       2
# 8       3
# 9       3
# 10      4
# 11      2
# 12      1
# 13      2
# 14      4
# 15      4
# 16      3
# 17      4
# 18      1
# 19      3
# 20      4
# 23      1
# 52      1
# 66      1
# 84      1
# 102     1
# 103     1
# 105     1
# 113     1
# 115     1
# 131     1
# Name: Seats Won, dtype: int64

# %% [markdown]
# # 9. find the Maximum Percentage of each No of Candidates

# %%
p=lp.groupby('No of Candidates').max()['Percentage']
p
# Out:
# No of Candidates
# 1      2053.00
# 2         6.03
# 3         7.19
# 4        10.38
# 5         1.75
# 6        15.85
# 7        19.09
# 8         0.16
# 9        20.72
# 10       22.88
# 11       29.13
# 12       27.90
# 13       33.27
# 14       30.54
# 15       31.10
# 16       38.78
# 17       41.71
# 18       10.33
# 19       10.39
# 20        4.51
# 23        2.42
# 52        2.63
# 66        0.92
# 84        2.07
# 102       1.30
# 103       1.16
# 105       3.99
# 113       0.79
# 115      10.87
# 131       0.94
# Name: Percentage, dtype: float64

# %% [markdown]
# # 10. find the Total Votes of each No of Political Party

# %%
p=lp.groupby('Political Party').sum()['Votes']
p
# Out:
# Political Party
#   All Kerala MGR Dravida Munnetra Party ADMP              2158
#   Communist Party of India (Marxist-Leninist) CPML        3270
#   Communist Party of India (Marxist-Leninist) CPML       23201
#   Communist Party of India CPI                         1364010
#   Independents (Janata) SJP                               5441
#                                                         ...
# Others / Independents IND                              1004323
# Revolutionary Socialist Party (Bolshevik) RSPB           43051
# Revolutionary Socialist Party RSP                       631771
# Social Action Party SAP                                    682
# Socialist Republican Party SRP                          162104
# Name: Votes, Length: 122, dtype: int64

# %% [markdown]
# # 11. find the Number of Political Party

# %%
lp['Political Party'].value_counts()
# Out:
# Communist Party of India (Marxist) CPM                 4
# Indian National Congress (Indira) INCI                 4
# Others / Independents IND                              4
# Indian Union Muslim League IUML                        4
#  Bharatiya Janata Party BJP                            4
#                                                       ..
#   Indian National Congress (Indira) INCI               1
#  Independents DLP                                      1
#   Communist Party of India (Marxist-Leninist) CPML     1
#  UDF supported Independents UDF                        1
#  Samajwadi Forward Block SFB                           1
# Name: Political Party, Length: 122, dtype: int64

# %% [markdown]
# # 12. create a bar chart number of year

# %%
lp['year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # 13. Draw a Histogram using the year

# %%
lp['year'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # 14. Draw a pie chart using the Seats Won

# %%
lp['Seats Won'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Seats Won'>

# %% [markdown]
# # 15.Draw a pie chart using the Percentage

# %%
lp['Percentage'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Percentage'>
