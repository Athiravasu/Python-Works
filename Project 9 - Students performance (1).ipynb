# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
st=pd.read_excel('StudentsPerformance1.xlsx')
st
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch  Column  Column.1 test preparation course  math score  \
# 0         standard     NaN       NaN                    none        72.0
# ...

# %%
st.head(2)
# Out:
#    Student ID  gender race/ethnicity parental level of education     lunch  \
# 0           1  female        group B           bachelor's degree  standard
# 1           2  female        group C                     Diploma  standard
#
#    Column  Column.1 test preparation course  math score  reading score  \
# 0     NaN       NaN                    none        72.0           72.0
# 1     NaN       NaN               completed        69.0           90.0
#
#    writing score
# 0           74.0
# 1           88.0

# %%
st1=st.copy()

# %%
st1.drop(['Column','Column.1'], axis=1, inplace=True)

# %%
#1.check whether null values are present in the given data.
st1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student ID                   1005 non-null   int64
#  1   gender                       1005 non-null   object
#  2   race/ethnicity               1005 non-null   object
#  3   parental level of education  1005 non-null   object
#  4   lunch                        1005 non-null   object
#  5   test preparation course      1005 non-null   object
#  6   math score                   1000 non-null   float64
#  7   reading score                1000 non-null   float64
#  8   writing score                1000 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 70.8+ KB

# %%
st1.isna().sum()
# Out:
# Student ID                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     5
# reading score                  5
# writing score                  5
# dtype: int64

# %%
#st=st.fillna().mean()
#st.head(3)
#st.median()
st1.median()
st2=st1.fillna(st1.median())
st2.head(5)
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\864920676.py:4: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   st1.median()
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\864920676.py:5: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   st2=st1.fillna(st1.median())
#    Student ID  gender race/ethnicity parental level of education  \
# 0           1  female        group B           bachelor's degree
# 1           2  female        group C                     Diploma
# ...

# %%
st2['score']=st2['math score']+st2['reading score']+st2['writing score']
st2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %%
#2.find the total number of students.

st2['Student ID'].count()
# Out:
# 1005

# %%
#3. find the average for reading score.

st2['reading score'].mean()
# Out:
# 69.1731343283582

# %%
#4.check the descriptive statistics for writing score.

st2.describe()['writing score']
# Out:
# count    1005.000000
# mean       68.058706
# std        15.157918
# min        10.000000
# 25%        58.000000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
#5.find how many students had completed the test preparation.

st2['test preparation course'].value_counts()
# Out:
# none         644
# completed    361
# Name: test preparation course, dtype: int64

# %%
# completed = 361

# %%
#6.find the min score in math.

st2.min()['math score']
# Out:
# 0.0

# %%
#7.find the max score in writing.

st2['math score'].max()
# Out:
# 100.0

# %%
#8.find the number of students by lunch.

st2.groupby('lunch').min()['Student ID']
# Out:
# lunch
# free/reduced    4
# standard        1
# Name: Student ID, dtype: int64

# %%
#9.find the average score for each by race/ethnicity.


st2.groupby('race/ethnicity').mean()['score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\3133581525.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby('race/ethnicity').mean()['score']
# race/ethnicity
# group A    189.329670
# group B    196.450262
# group C    201.406250
# group D    207.538168
# group E    218.163121
# Name: score, dtype: float64

# %%
#10.create a count plot for parental level of education.

sns.countplot(x=st["parental level of education"])
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %%
#11. Find the total score of each student

st2.groupby('Student ID').sum()['score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\2165779454.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby('Student ID').sum()['score']
# Student ID
# 1       218.0
# 2       247.0
# 3       278.0
# 4       148.0
# 5       229.0
#         ...
# 1001    282.0
# 1002    172.0
# 1003    195.0
# 1004    223.0
# 1005    249.0
# Name: score, Length: 1005, dtype: float64

# %%
#12.What is the average of total score for male and female students?

st2.groupby('gender').mean()['score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\991873993.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby('gender').mean()['score']
# gender
# female    208.687140
# male      197.543388
# Name: score, dtype: float64

# %%
#13. What is the average of total score by gender and parental education level?

st2.groupby(['gender','parental level of education']).mean()['score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\2686482317.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby(['gender','parental level of education']).mean()['score']
# gender  parental level of education
# female  Diploma                        212.941176
#         associate's degree             213.370690
#         bachelor's degree              223.718750
#         high school                    195.448649
#         master's degree                220.513514
# male    Diploma                        197.148148
#         associate's degree             203.616822
#         bachelor's degree              206.327273
#         high school                    189.062827
#         master's degree                220.565217
# Name: score, dtype: float64

# %%
#14. What is the average math score by race/ethnicity?

st2.groupby('race/ethnicity').mean()['math score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\2751594778.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby('race/ethnicity').mean()['math score']
# race/ethnicity
# group A    61.725275
# group B    63.465969
# group C    64.468750
# group D    67.362595
# group E    73.765957
# Name: math score, dtype: float64

# %%
#15.Find the number of Students by test preparation course

st2.groupby('test preparation course').count()['Student ID']
# Out:
# test preparation course
# completed    361
# none         644
# Name: Student ID, dtype: int64

# %%
#16. Find the average total score by test preparation course

st2.groupby('test preparation course').mean()['score']
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_27748\3076090910.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st2.groupby('test preparation course').mean()['score']
# test preparation course
# completed    217.900277
# none         195.147516
# Name: score, dtype: float64

# %%
#17. create a new variable as, 'Score', and the values in the column should be the sum of all the three papers.

st2[' Total Score']=(st2['math score']+st2['reading score']+st2['writing score'])/300*3
st2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %%
#18. create a new variable as, " Percentage", and find the percentage for the score 

st2['Percentage']=st2['math score']+st2['reading score']+st2['writing score']/(300*100)
st2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %%
#19. create a new variable called, 'status'. Inside this column, find the status as Pass \ Fail, those who score abol pass the examve 40 % wil

passmark=40
st2['maths status']=np.where(st2['math score']>passmark,'pass','fail')
st2['reading status']=np.where(st2['reading score']>passmark,'pass','fail')
st2['writing status']=np.where(st2['writing score']>passmark,'pass','fail')
st2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %%
#percentage
#task1['score']=(task1['math score']+task1['reading score']+task1['writing score'])/300*(100)
#task1

# %%
st2['status'] = st2.apply(lambda x : 'Fail' if x['maths status'] == 'Fail' or x['reading status'] == 'Fail' or x['writing status'] == 'Fail' else 'Pass', axis = 1)
st2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %% [markdown]
# 20. create a pie chart using the status column

# %%
st2['status'].value_counts().plot(kind="pie", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='status'>
