# %%
import pandas as pd
data=pd.read_excel('Inventory.xlsx')
data
# Out:
#                                Product Name         Category  Quantity  Price  \
# 0               Enermax Note Cards, Premium  Office Supplies         3     45
# 1        Dania Corner Shelving, Traditional        Furniture         7    854
# 2     Binney & Smith Sketch Pad, Easy-Erase  Office Supplies         3    140
# 3                Boston Markers, Easy-Erase  Office Supplies         2     27
# 4               Eldon Folders, Single Width  Office Supplies         2     17
# ...                                     ...              ...       ...    ...
# 8042   Ikea Stackable Bookrack, Traditional        Furniture         2    245
# 8043      BIC Pencil Sharpener, Fluorescent  Office Supplies         2     30
# 8044          Avery Binder Covers, Recycled  Office Supplies         4     23
# 8045                    StarTech Phone, Red       Technology         3    108
# 8046              Motorola Audio Dock, VoIP       Technology         5    867
#
# ...

# %% [markdown]
# # Find the total stock

# %%
a=data['Quantity'].sum()
a
# Out:
# 30354

# %% [markdown]
# # Find the total amount of the stock

# %%
a=data['Amount of Products'].sum()
a
# Out:
# 11898983

# %% [markdown]
# # Find the number of Categories

# %%
a=data['Category'].value_counts()
a
# Out:
# Office Supplies    5286
# Technology         1523
# Furniture          1238
# Name: Category, dtype: int64

# %% [markdown]
# #  Find the number of products in each category.

# %%
a=data.groupby('Category').count()['Amount of Products']
a
# Out:
# Category
# Furniture          1238
# Office Supplies    5286
# Technology         1523
# Name: Amount of Products, dtype: int64

# %% [markdown]
# # Find the number of Suppliers

# %%
a=data['Supplier'].count()
a
# Out:
# 8047

# %% [markdown]
# # create a bar plot using the number of suppliers and modify the chart

# %%
data['Supplier'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Create a Pie chart using the percentage values of number of categories

# %%
a=data['Category'].value_counts(normalize=True)
a
# Out:
# Office Supplies    0.656891
# Technology         0.189263
# Furniture          0.153846
# Name: Category, dtype: float64

# %%
a.plot(kind='pie',autopct='1%.2f%%')
# Out:
# <Axes: ylabel='Category'>

# %% [markdown]
# # Create a list of suppliers and remove Guillermo Plant supplier from the list

# %%
list=['kathy Robinson','Ashley Upright','Guillermo Plant','Josephine Lee','Leonard Angelo','Oscar Williams']
list
# Out:
# ['kathy Robinson',
#  'Ashley Upright',
#  'Guillermo Plant',
#  'Josephine Lee',
#  'Leonard Angelo',
#  'Oscar Williams']

# %%
list.remove('Guillermo Plant')
list
# Out:
# ['kathy Robinson',
#  'Ashley Upright',
#  'Josephine Lee',
#  'Leonard Angelo',
#  'Oscar Williams']

# %% [markdown]
# # Identify which category of products are more sold

# %%
a=data.groupby('Category').sum()['Quantity']
a
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_3292\1266945380.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=data.groupby('Category').sum()['Quantity']
# Category
# Furniture           4641
# Office Supplies    19902
# Technology          5811
# Name: Quantity, dtype: int64

# %% [markdown]
# # Identify which category of products are least sold.

# %%
a=data.groupby('Category').min()['Quantity']
a

# %% [markdown]
# # Identify which supplier has done more sales

# %%
a=data.groupby('Supplier').sum()['Amount of Products']
a
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_3292\2898037019.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=data.groupby('Supplier').sum()['Amount of Products']
# Supplier
# Ada Pappas            1821
# Ada Stanley             10
# Alexandra Martino     5975
# Alvin Franks           360
# Amanda Cooper         8458
#                      ...
# Thomas Grimm          4449
# Thomas Lucas         26696
# Thomas Mauer           908
# Thomas Watson         5285
# Timothy Cluff         5038
# Name: Amount of Products, Length: 416, dtype: int64
