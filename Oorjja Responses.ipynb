# %%
 import pandas as pd
    
 Oorjja2 = pd.read_excel('Oorjja (Responses).xlsx')
 Oorjja2
# Out:
#                 Timestamp                Email address             Name  \
# 0 2023-04-12 10:02:14.576       rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677           anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475    aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104         ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463     jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065      Kanjanyathira@gmail.com       Athira p v
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# ...

# %%
Oorjja2.head()
# Out:
#                 Timestamp              Email address             Name  \
# 0 2023-04-12 10:02:14.576     rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
Oorjja2.tail()
# Out:
#                 Timestamp                Email address             Name  \
# 5 2023-04-12 10:08:47.065      Kanjanyathira@gmail.com       Athira p v
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
# 8  Ernakulam     Trainee  Female         O+ve      Degree (Graduation)   23
# 9     Idukki      Mentor  Female         O-ve      Degree (Graduation)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
Oorjja2.shape
# Out:
# (10, 21)

# %%
Oorjja2.columns
# Out:
# Index(['Timestamp', 'Email address', 'Name', 'District', 'Designation',
#        'Gender', 'Blood grouop', 'Education', 'Age', 'Family members',
#        'Shirt size', 'No. of knives at home', 'No. of chairs at home',
#        'Favorite color (mention only one)', 'Liter of milk bought in home',
#        'Height ( in cm)', 'Weight ( in Kg)', 'which is your favorite subject',
#        'Which is your favorite Software',
#        'How many liter of water you drink daily', 'Favorite food '],
#       dtype='object')

# %%
Oorjja2.dtypes
# Out:
# Timestamp                                  datetime64[ns]
# Email address                                      object
# Name                                               object
# District                                           object
# Designation                                        object
# Gender                                             object
# Blood grouop                                       object
# Education                                          object
# Age                                                 int64
# Family members                                     object
# Shirt size                                         object
# No. of knives at home                              object
# No. of chairs at home                              object
# Favorite color (mention only one)                  object
# Liter of milk bought in home                       object
# Height ( in cm)                                     int64
# ...

# %%
Oorjja2.median()
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_8536\521068803.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Oorjja2.median()
# C:\Users\athir\AppData\Local\Temp\ipykernel_8536\521068803.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Oorjja2.median()
# Age                                         23.50
# Height ( in cm)                            152.50
# Weight ( in Kg)                             49.50
# How many liter of water you drink daily      1.75
# dtype: float64

# %%
Oorjja2.mean()
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_8536\3997890605.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Oorjja2.mean()
# C:\Users\athir\AppData\Local\Temp\ipykernel_8536\3997890605.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Oorjja2.mean()
# Age                                         24.70
# Height ( in cm)                            154.00
# Weight ( in Kg)                             52.90
# How many liter of water you drink daily      1.61
# dtype: float64

# %%
Oorjja2.mode()
# Out:
#                 Timestamp                Email address             Name  \
# 0 2023-04-12 10:02:14.576      Kanjanyathira@gmail.com          Ajesh C
# 1 2023-04-12 10:02:48.677         ajeshc1992@gmail.com  Akshara Vincent
# 2 2023-04-12 10:04:18.475    aksharavincent7@gmail.com         Alfy N P
# 3 2023-04-12 10:06:17.104         alfynp2000@gmail.com         Anju P K
# 4 2023-04-12 10:08:34.463           anjupk84@gmail.com       Athira p v
# 5 2023-04-12 10:08:47.065    christy123johns@gmail.com  Catherine Johns
# 6 2023-04-12 10:09:44.593    christy231johns@gmail.com    Christy Johns
# 7 2023-04-12 10:10:12.832     jiyaparackal00@gmail.com      Jiyamol Joy
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457       rithunhomiez@gmail.com       Rithun P C
#
#     District Designation  Gender Blood grouop            Education   Age  \
# 0  Ernakulam     Trainee  Female         B+ve  Degree (Graduation)  21.0
# ...

# %%
Oorjja2.min()
# Out:
# Timestamp                                  2023-04-12 10:02:14.576000
# Email address                                 Kanjanyathira@gmail.com
# Name                                                          Ajesh C
# District                                                    Alappuzha
# Designation                                                    Mentor
# Gender                                                         Female
# Blood grouop                                                     A+ve
# Education                                     12th (Higher Secondary)
# Age                                                                21
# Family members                                                    3-4
# Shirt size                                                          M
# No. of knives at home                                             0-3
# No. of chairs at home                                             0-5
# ...

# %%
Oorjja2.max()
# Out:
# Timestamp                                  2023-04-12 10:15:21.457000
# Email address                                  rithunhomiez@gmail.com
# Name                                                       Rithun P C
# District                                                     Thrissur
# Designation                                                   Trainee
# Gender                                                           Male
# Blood grouop                                                     O-ve
# Education                                     Degree(Post Graduation)
# Age                                                                30
# Family members                                                    5-6
# Shirt size                                                         XS
# No. of knives at home                                             4-6
# No. of chairs at home                                            6-10
# ...

# %%
Oorjja2['Age'] #series form
# Out:
# 0    27
# 1    29
# 2    21
# 3    30
# 4    27
# 5    23
# 6    22
# 7    24
# 8    23
# 9    21
# Name: Age, dtype: int64

# %%
Oorjja2[['Age']]
# Out:
#    Age
# 0   27
# 1   29
# 2   21
# 3   30
# 4   27
# 5   23
# 6   22
# 7   24
# 8   23
# 9   21

# %%
Oorjja2[['Age','Gender']]
# Out:
#    Age  Gender
# 0   27    Male
# 1   29  Female
# 2   21  Female
# 3   30    Male
# 4   27  Female
# 5   23  Female
# 6   22  Female
# 7   24  Female
# 8   23  Female
# 9   21  Female

# %%
Oorjja2[['Age']].head()
# Out:
#    Age
# 0   27
# 1   29
# 2   21
# 3   30
# 4   27

# %%
Oorjja2[['Gender']].tail(2)
# Out:
#    Gender
# 8  Female
# 9  Female

# %%
Oorjja2[['Age','Gender']].head(3)
# Out:
#    Age  Gender
# 0   27    Male
# 1   29  Female
# 2   21  Female

# %%
Oorjja2.sample(5)
# Out:
#                 Timestamp                Email address            Name  \
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com        Alfy N P
# 4 2023-04-12 10:08:34.463     jiyaparackal00@gmail.com     Jiyamol Joy
# 0 2023-04-12 10:02:14.576       rithunhomiez@gmail.com      Rithun P C
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com  Remya Raghavan
# 3 2023-04-12 10:06:17.104         ajeshc1992@gmail.com         Ajesh C
#
#     District Designation  Gender Blood grouop            Education  Age  \
# 6  Ernakulam     Trainee  Female         B+ve  Degree (Graduation)   22
# 4  Ernakulam     Trainee  Female         B+ve  Degree (Graduation)   27
# 0  Kozhikode     Trainee    Male         B+ve  Degree (Graduation)   27
# 8  Ernakulam     Trainee  Female         O+ve  Degree (Graduation)   23
# 3  Alappuzha     Trainee    Male         B+ve  Degree (Graduation)   30
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
Oorjja2.sample(2)
# Out:
#                 Timestamp           Email address        Name   District  \
# 0 2023-04-12 10:02:14.576  rithunhomiez@gmail.com  Rithun P C  Kozhikode
# 1 2023-04-12 10:02:48.677      anjupk84@gmail.com    Anju P K  Kozhikode
#
#   Designation  Gender Blood grouop            Education  Age Family members  \
# 0     Trainee    Male         B+ve  Degree (Graduation)   27            5-6
# 1     Trainee  Female         A+ve  Degree (Graduation)   29            3-4
#
#    ... No. of knives at home No. of chairs at home  \
# 0  ...                   0-3                  6-10
# 1  ...                   4-6                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 0                             Black                      1 - 1.5
# 1                              Rose                      0.5 - 1
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# 0             176               68                  Data Analytics
# ...

# %%
Oorjja2[['Age','Gender']].sample(3)
# Out:
#    Age  Gender
# 6   22  Female
# 7   24  Female
# 3   30    Male

# %%
Oorjja2[1:5]
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 1            3-4  ...                   4-6                  6-10
# 2            3-4  ...                   4-6                  6-10
# ...

# %%
Oorjja2[2:7]
# Out:
#                 Timestamp              Email address             Name  \
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com       Athira p v
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com         Alfy N P
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
Oorjja2[3:8]
# Out:
#                 Timestamp              Email address           Name  \
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com        Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com    Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com     Athira p v
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com       Alfy N P
# 7 2023-04-12 10:10:12.832  christy123johns@gmail.com  Christy Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
Oorjja2[-1:]
# Out:
#                 Timestamp              Email address             Name  \
# 9 2023-04-12 10:15:21.457  christy231johns@gmail.com  Catherine Johns
#
#   District Designation  Gender Blood grouop            Education  Age  \
# 9   Idukki      Mentor  Female         O-ve  Degree (Graduation)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 9            3-4  ...                   0-3                16- 20
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 9                             Black                   Not buying
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# 9             149               45                  Data Analytics
#
#   Which is your favorite Software How many liter of water you drink daily  \
# 9                   Excel and PBI                                     2.0
#
#    Favorite food
# 9             Veg
#
# [1 rows x 21 columns]

# %%
Oorjja2[-3:]
# Out:
#                 Timestamp                Email address             Name  \
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
# 8  Ernakulam     Trainee  Female         O+ve      Degree (Graduation)   23
# 9     Idukki      Mentor  Female         O-ve      Degree (Graduation)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 7            3-4  ...                   4-6                 11-15
# 8            5-6  ...                   0-3                  6-10
# 9            3-4  ...                   0-3                16- 20
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# ...

# %%
Oorjja2[1:-3]
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com       Athira p v
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com         Alfy N P
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# ...

# %%
Oorjja2['Gender'].value_counts() # counts
# Out:
# Female    8
# Male      2
# Name: Gender, dtype: int64

# %%
a = Oorjja2['Gender'].value_counts(normalize =True) # to show the perentage value of the counts
a
# Out:
# Female    0.8
# Male      0.2
# Name: Gender, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
Oorjja2 = pd.read_excel('Oorjja (Responses).xlsx')
Oorjja2.head() #head
# Out:
#                 Timestamp              Email address             Name  \
# 0 2023-04-12 10:02:14.576     rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
a.plot(kind ='pie')
# Out:
# <Axes: ylabel='Gender'>

# %%
b = Oorjja2['Gender'].value_counts()
b
# Out:
# Female    8
# Male      2
# Name: Gender, dtype: int64

# %%
b.plot(kind= 'bar')
# Out:
# <Axes: >

# %%
a=Oorjja2['District'].value_counts()
a
# Out:
# Ernakulam    4
# Kozhikode    2
# Kannur       1
# Alappuzha    1
# Thrissur     1
# Idukki       1
# Name: District, dtype: int64

# %%
a.plot(kind ='pie')
a
# Out:
# Ernakulam    4
# Kozhikode    2
# Kannur       1
# Alappuzha    1
# Thrissur     1
# Idukki       1
# Name: District, dtype: int64

# %%
b.plot(kind= 'bar')
b
# Out:
# Female    8
# Male      2
# Name: Gender, dtype: int64

# %%
b = Oorjja2['Blood grouop'].value_counts()
b
# Out:
# B+ve    4
# O+ve    3
# A+ve    2
# O-ve    1
# Name: Blood grouop, dtype: int64

# %%
Oorjja2[['District']]
# Out:
#     District
# 0  Kozhikode
# 1  Kozhikode
# 2     Kannur
# 3  Alappuzha
# 4  Ernakulam
# 5   Thrissur
# 6  Ernakulam
# 7  Ernakulam
# 8  Ernakulam
# 9     Idukki

# %%
b= Oorjja2['District'].value_counts()
b
# Out:
# Ernakulam    4
# Kozhikode    2
# Kannur       1
# Alappuzha    1
# Thrissur     1
# Idukki       1
# Name: District, dtype: int64

# %%
b.plot(kind= 'bar')
b
# Out:
# Ernakulam    4
# Kozhikode    2
# Kannur       1
# Alappuzha    1
# Thrissur     1
# Idukki       1
# Name: District, dtype: int64
