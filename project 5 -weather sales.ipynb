# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_line1={
     
     'Day': ['Mon 08','Tue 09','wed 10','thu 11','fri 12','sun 14','Mon 15','tue 16','Mon 15','Tue 16'],
    'Temperature':[32,31,30,30,29,29,28,28,28,28] 
}

df_line = pd.DataFrame(df_line1)
df_line
# Out:
#       Day  Temperature
# 0  Mon 08           32
# 1  Tue 09           31
# 2  wed 10           30
# 3  thu 11           30
# 4  fri 12           29
# 5  sun 14           29
# 6  Mon 15           28
# 7  tue 16           28
# 8  Mon 15           28
# 9  Tue 16           28

# %%
df_line.plot('Day','Temperature')
# Out:
# <Axes: xlabel='Day'>
