# %%
import pandas as pd
data=pd.read_excel('Inventory.xlsx')
data
# Out:
#                                Product Name         Category  Quantity  Price  \
# 0               Enermax Note Cards, Premium  Office Supplies         3     45
# 1        Dania Corner Shelving, Traditional        Furniture         7    854
# 2     Binney & Smith Sketch Pad, Easy-Erase  Office Supplies         3    140
# 3                Boston Markers, Easy-Erase  Office Supplies         2     27
# 4               Eldon Folders, Single Width  Office Supplies         2     17
# ...                                     ...              ...       ...    ...
# 8042   Ikea Stackable Bookrack, Traditional        Furniture         2    245
# 8043      BIC Pencil Sharpener, Fluorescent  Office Supplies         2     30
# 8044          Avery Binder Covers, Recycled  Office Supplies         4     23
# 8045                    StarTech Phone, Red       Technology         3    108
# 8046              Motorola Audio Dock, VoIP       Technology         5    867
#
#       Amount of Products             Supplier Order Date
# 0                    135       Kathy Robinson 2011-01-01
# 1                   5978        Eric Hatchett 2011-01-03
# 2                    420       Ashley Upright 2011-01-04
# 3                     54  Christopher Francis 2011-01-04
# 4                     34     Gregory Williams 2011-01-04
# ...                  ...                  ...        ...
# 8042                 490        Josephine Lee 2014-12-31
# 8043                  60         Geri Holston 2014-12-31
# 8044                  92       Oscar Williams 2014-12-31
# 8045                 324        John Crenshaw 2014-12-31
# 8046                4335       Leonard Angelo 2014-12-31
#
# [8047 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product Name        8047 non-null   object
#  1   Category            8047 non-null   object
#  2   Quantity            8047 non-null   int64
#  3   Price               8047 non-null   int64
#  4   Amount of Products  8047 non-null   int64
#  5   Supplier            8047 non-null   object
#  6   Order Date          8047 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 440.2+ KB

# %%
data.head()
# Out:
#                             Product Name         Category  Quantity  Price  \
# 0            Enermax Note Cards, Premium  Office Supplies         3     45
# 1     Dania Corner Shelving, Traditional        Furniture         7    854
# 2  Binney & Smith Sketch Pad, Easy-Erase  Office Supplies         3    140
# 3             Boston Markers, Easy-Erase  Office Supplies         2     27
# 4            Eldon Folders, Single Width  Office Supplies         2     17
#
#    Amount of Products             Supplier Order Date
# 0                 135       Kathy Robinson 2011-01-01
# 1                5978        Eric Hatchett 2011-01-03
# 2                 420       Ashley Upright 2011-01-04
# 3                  54  Christopher Francis 2011-01-04
# 4                  34     Gregory Williams 2011-01-04

# %% [markdown]
# # Find the total stock

# %%
data.sum()
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_3812\1263598667.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.sum()
# Product Name          Enermax Note Cards, PremiumDania Corner Shelvi...
# Category              Office SuppliesFurnitureOffice SuppliesOffice ...
# Quantity                                                          30354
# Price                                                           2348482
# Amount of Products                                             11898983
# Supplier              Kathy RobinsonEric HatchettAshley UprightChris...
# dtype: object

# %% [markdown]
# # Find the total stock

# %%
a=data['Quantity'].value_counts().sum()
a
# Out:
# 8047

# %% [markdown]
# # Find the total amount of the stock

# %%
a=data.groupby('Quantity').sum()['Amount of Products']
a
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_3812\3533053433.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=data.groupby('Quantity').sum()['Amount of Products']
# Quantity
# 1       54779
# 2      631748
# 3     1348194
# 4     1220056
# 5     1786320
# 6     1263612
# 7     1887956
# 8      940584
# 9     1210437
# 10     344470
# 11     425898
# 12     273144
# 13     235495
# 14     276290
# Name: Amount of Products, dtype: int64

# %% [markdown]
# # Find the number of Categories

# %%
a=data['Category'].value_counts().sum()
a
# Out:
# 8047

# %% [markdown]
# #  Find the number of products in each category.

# %%
a=data.groupby('Category').sum()['Amount of Products']
a
# Out:
# C:\Users\athir\AppData\Local\Temp\ipykernel_3812\3783661524.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=data.groupby('Category').sum()['Amount of Products']
# Category
# Furniture          3130898
# Office Supplies    4211371
# Technology         4556714
# Name: Amount of Products, dtype: int64

# %% [markdown]
# # Find the number of Suppliers

# %%
a=data['Supplier'].value_counts().sum()
a
# Out:
# 8047

# %% [markdown]
# # create a bar plot using the number of suppliers and modify the chart

# %%
data['Supplier'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Supplier'>

# %% [markdown]
# # Create a Pie chart using the percentage values of number of categories

# %%
data['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Category'>

# %% [markdown]
# # Create a list of suppliers and remove Guillermo Plant supplier from the list

# %%
list.clear()

# %%
list=['Bush Floating Shelf Set, Pine','3','140.00','420.00','04-01-2011','Furniture','Guillermo Plant']
list
# Out:
# ['Bush Floating Shelf Set, Pine',
#  '3',
#  '140.00',
#  '420.00',
#  '04-01-2011',
#  'Furniture',
#  'Guillermo Plant']

# %%
list.remove('Guillermo Plant')
list
# Out:
# ['Bush Floating Shelf Set, Pine',
#  '3',
#  '140.00',
#  '420.00',
#  '04-01-2011',
#  'Furniture']

# %% [markdown]
# # Identify which category of products are more sold

# %%
a=data.groupby('Category').max()['Amount of Products']
a
# Out:
# Category
# Furniture          80206
# Office Supplies    78204
# Technology         66472
# Name: Amount of Products, dtype: int64

# %% [markdown]
# # Identify which category of products are least sold.

# %%
a=data.groupby('Category').min()['Amount of Products']
a
# Out:
# Category
# Furniture          11
# Office Supplies     3
# Technology         20
# Name: Amount of Products, dtype: int64

# %% [markdown]
# # Identify which supplier has done more sales

# %%
a=data.groupby('Price').max()['Supplier']
a
# Out:
# Price
# 3              Juan Soler
# 4              Opal Jones
# 5             Pete Orozco
# 6       Michael Mackenzie
# 7            Richard Lugo
#               ...
# 5725         Judy Sanches
# 5726         Marie Molden
# 5729        Marcus Darden
# 5785        Harry Collier
# 6517         Kenneth Long
# Name: Supplier, Length: 1248, dtype: object
